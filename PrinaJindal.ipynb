# %%
a = int(input("enter any number"))
b = int(input("enter any number part 2"))
if a>b:
  print(a,">",b)
else:
  print(a,"<",b)
# Out:
# enter any number7
# enter any number part 20
# 7 > 0

# %%
s = 0
for i in range(1,5):
  s= i+s
print("sum is = ", s)
# Out:
# sum is =  10

# %%
q = int(input("enter no."))
if q % 2==0:
  print(q,"is even")
else:
  print(q,"is odd")
# Out:
# enter no.6
# 6 is even

# %%
data = []
with open ('data.txt', 'r') as  file:
  for line in file:
    studentEntry = list(line.strip().split('    '))
    data.append(studentEntry)

# %%
(data)
# Out:
# [['Roll', 'Name', 'Marks(100)'],
#  ['1001', 'satara', '43'],
#  ['1002', 'britiney', '38'],
#  ['1003', 'rory', '51'],
#  ['1004', 'charelle', '14'],
#  ['1005', 'elizeo', '97'],
#  ['1006', 'dago', '87'],
#  ['1007', 'poetry', '63'],
#  ['1008', 'jhase', '33'],
#  ['1009', 'derika', '79'],
#  ['1010', 'larsen', '93'],
#  ['1011', 'jazzmon', '6'],
#  ['1012', 'katianna', '98'],
#  ['1013', 'ayodeji', '47'],
#  ['1014', 'destane', '28'],
#  ['1015', 'nechole', '28'],
#  ['1016', 'destani', '99'],
#  ['1017', 'deklyn', '23'],
#  ['1018', 'surafel', '28'],
#  ['1019', 'aixa', '35'],
#  ['1020', 'patryck', '47'],
#  ['1021', 'carrisa', '55'],
#  ['1022', 'destany', '9'],
#  ['1023', 'cael', '27'],
#  ['1024', 'elea', '71'],
#  ['1025', 'valli', '39'],
#  ['1026', 'issaac', '76'],
#  ['1027', 'blade', '98'],
#  ['1028', 'ayleen', '85'],
#  ['1029', 'elen', '74'],
#  ['1030', 'jorell', '78'],
#  ['1031', 'lyberti', '11'],
#  ['1032', 'milissa', '0'],
#  ['1033', 'faizon', '34'],
#  ['1034', 'kerrion', '95'],
#  ['1035', 'marlita', '61'],
#  ['1036', 'johnita', '2'],
#  ['1037', 'rayleigh', '66'],
#  ['1038', 'courtany', '9'],
#  ['1039', 'daryel', '57'],
#  ['1040', 'loey', '77'],
#  ['1041', 'navayah', '37'],
#  ['1042', 'misti', '94'],
#  ['1043', 'nonnie', '100'],
#  ['1044', 'ramonia', '52'],
#  ['1045', 'danamarie', '11'],
#  ['1046', 'samatha', '50'],
#  ['1047', 'hamilton', '42'],
#  ['1048', 'antwion', '3'],
#  ['1049', 'jaeline', '47'],
#  ['1050', 'nashiya', '23'],
#  ['1051', 'silvino', '27'],
#  ['1052', 'kathrynne', '92'],
#  ['1053', 'shantee', '29'],
#  ['1054', 'umeka', '77'],
#  ['1055', 'shantea', '30'],
#  ['1056', 'shantel', '40'],
#  ['1057', 'ferlin', '94'],
#  ['1058', 'debroh', '96'],
#  ['1059', 'bronda', '94'],
#  ['1060', 'jewelz', '84'],
#  ['1061', 'ginger', '54'],
#  ['1062', 'ladarion', '10'],
#  ['1063', 'jewell', '60'],
#  ['1064', 'swayze', '20'],
#  ['1065', 'isley', '30'],
#  ['1066', 'dexter', '54'],
#  ['1067', 'harvey', '10'],
#  ['1068', 'shanitra', '28'],
#  ['1069', 'henchy', '98'],
#  ['1070', 'kimberleigh', '61'],
#  ['1071', 'ellarie', '38'],
#  ['1072', 'leiland', '95'],
#  ['1073', 'halona', '15'],
#  ['1074', 'bryanah', '96'],
#  ['1075', 'dazhane', '86'],
#  ['1076', 'leilani', '44'],
#  ['1077', 'vernon', '4'],
#  ['1078', 'mersades', '4'],
#  ['1079', 'lenzie', '46'],
#  ['1080', 'taide', '45'],
#  ['1081', 'jarexy', '66'],
#  ['1082', 'randell', '62'],
#  ['1083', 'leilany', '50'],
#  ['1084', 'glenna', '80'],
#  ['1085', 'ondina', '38'],
#  ['1086', 'timtohy', '62'],
#  ['1087', 'ziair', '11'],
#  ['1088', 'patryce', '73'],
#  ['1089', 'tatayana', '7'],
#  ['1090', 'kynadie', '46'],
#  ['1091', 'zalaya', '81'],
#  ['1092', 'ondine', '36'],
#  ['1093', 'adamari', '8'],
#  ['1094', 'indigo', '69'],
#  ['1095', 'edgardo', '88'],
#  ['1096', 'taseen', '73'],
#  ['1097', 'adamary', '91'],
#  ['1098', 'kayci', '17'],
#  ['1099', 'anquette', '61'],
#  ['1100', 'kayce', '17'],
#  ['1101', 'saharra', '46'],
#  ['1102', 'bradrick', '39'],
#  ['1103', 'estanislao', '49'],
#  ['1104', 'joquan', '46'],
#  ['1105', 'navie', '66'],
#  ['1106', 'navid', '36'],
#  ['1107', 'navil', '81'],
#  ['1108', 'navin', '27'],
#  ['1109', 'rakita', '7'],
#  ['1110', 'khylei', '20'],
#  ['1111', 'raiquan', '96'],
#  ['1112', 'mihail', '0'],
#  ['1113', 'shaquela', '98'],
#  ['1114', 'maccoy', '1'],
#  ['1115', 'elek', '95'],
#  ['1116', 'shaquell', '12'],
#  ['1117', 'jazalyn', '51'],
#  ['1118', 'briaunna', '70'],
#  ['1119', 'addam', '34'],
#  ['1120', 'issaiah', '55'],
#  ['1121', 'suellyn', '98'],
#  ['1122', 'jayliana', '20'],
#  ['1123', 'cope', '13'],
#  ['1124', 'anjali', '65'],
#  ['1125', 'mabel', '33'],
#  ['1126', 'shimon', '70'],
#  ['1127', 'kiyara', '76'],
#  ['1128', 'willy', '32'],
#  ['1129', 'even', '14'],
#  ['1130', 'ashden', '74'],
#  ['1131', 'fabricio', '56'],
#  ['1132', 'akaash', '20'],
#  ['1133', 'averly', '85'],
#  ['1134', 'haadi', '55'],
#  ['1135', 'jazelyn', '83'],
#  ['1136', 'jannett', '0'],
#  ['1137', 'jayen', '56'],
#  ['1138', 'jayel', '62'],
#  ['1139', 'janneth', '52'],
#  ['1140', 'rayssa', '30'],
#  ['1141', 'sevrin', '24'],
#  ['1142', 'willa', '99'],
#  ['1143', 'robertson', '10'],
#  ['1144', 'reneta', '29'],
#  ['1145', 'wille', '98'],
#  ['1146', 'jannete', '70'],
#  ['1147', 'gwenyth', '6'],
#  ['1148', 'abbott', '6'],
#  ['1149', 'myan', '49'],
#  ['1150', 'trayvion', '68'],
#  ['1151', 'rubina', '54'],
#  ['1152', 'zareen', '85'],
#  ['1153', 'royer', '62'],
#  ['1154', 'montague', '47'],
#  ['1155', 'jaymarie', '51'],
#  ['1156', 'srihitha', '96'],
#  ['1157', 'smitha', '33'],
#  ['1158', 'kyren', '22'],
#  ['1159', 'tannar', '37'],
#  ['1160', 'macio', '96'],
#  ['1161', 'harriette', '9'],
#  ['1162', 'quintell', '47'],
#  ['1163', 'alok', '7'],
#  ['1164', 'wanita', '80'],
#  ['1165', 'macie', '43'],
#  ['1166', 'peytan', '25'],
#  ['1167', 'yevonne', '85'],
#  ['1168', 'xzayvion', '58'],
#  ['1169', 'jakhari', '54'],
#  ['1170', 'shams', '3'],
#  ['1171', 'enza', '41'],
#  ['1172', 'jameca', '39'],
#  ['1173', 'shama', '89'],
#  ['1174', 'jermeka', '50'],
#  ['1175', 'jaedah', '29'],
#  ['1176', 'idali', '30'],
#  ['1177', 'brayen', '97'],
#  ['1178', 'jaedan', '30'],
#  ['1179', 'karrisa', '45'],
#  ['1180', 'idaly', '88'],
#  ['1181', 'temeca', '59'],
#  ['1182', 'ziomara', '21'],
#  ['1183', 'kahlel', '12'],
#  ['1184', 'kahlen', '69'],
#  ['1185', 'susie', '22'],
#  ['1186', 'tanmay', '10'],
#  ['1187', 'toleen', '69'],
#  ['1188', 'kahlea', '7'],
#  ['1189', 'kahleb', '45'],
#  ['1190', 'aleina', '7'],
#  ['1191', 'janessa', '51'],
#  ['1192', 'vaishnavi', '62'],
#  ['1193', 'chivas', '1'],
#  ['1194', 'jeret', '85'],
#  ['1195', 'azumi', '98'],
#  ['1196', 'safia', '25'],
#  ['1197', 'joslin', '90'],
#  ['1198', 'corinne', '75'],
#  ['1199', 'diamond', '59'],
#  ['1200', 'amylah', '69'],
#  ['1201', 'corinna', '55'],
#  ['1202', 'phyliss', '63'],
#  ['1203', 'owyn', '56'],
#  ['1204', 'nigel', '17'],
#  ['1205', 'kimyra', '79'],
#  ['1206', 'adrina', '63'],
#  ['1207', 'ibrahima', '70'],
#  ['1208', 'carmin', '63'],
#  ['1209', 'mizraim', '11'],
#  ['1210', 'kateria', '98'],
#  ['1211', 'chanta', '38'],
#  ['1212', 'chante', '95'],
#  ['1213', 'mairin', '97'],
#  ['1214', 'aeriell', '88'],
#  ['1215', 'shenica', '73'],
#  ['1216', 'chanti', '87'],
#  ['1217', 'ishmeal', '85'],
#  ['1218', 'katerin', '74'],
#  ['1219', 'rosealie', '9'],
#  ['1220', 'danese', '39'],
#  ['1221', 'keidrick', '52'],
#  ['1222', 'kaja', '82'],
#  ['1223', 'aubrina', '75'],
#  ['1224', 'dafny', '4'],
#  ['1225', 'shaneiqua', '92'],
#  ['1226', 'takenya', '48'],
#  ['1227', 'avaya', '57'],
#  ['1228', 'binta', '7'],
#  ['1229', 'amyiah', '79'],
#  ['1230', 'appolonia', '84'],
#  ['1231', 'aaliyana', '98'],
#  ['1232', 'ciaran', '16'],
#  ['1233', 'zachory', '55'],
#  ['1234', 'aniyah', '47'],
#  ['1235', 'tarvis', '25'],
#  ['1236', 'lealani', '4'],
#  ['1237', 'lealand', '86'],
#  ['1238', 'daddy', '2'],
#  ['1239', 'rania', '97'],
#  ['1240', 'jaxan', '23'],
#  ['1241', 'dinasia', '92'],
#  ['1242', 'jalayla', '56'],
#  ['1243', 'xaria', '1'],
#  ['1244', 'zeth', '4'],
#  ['1245', 'jayleigh', '81'],
#  ['1246', 'zeta', '33'],
#  ['1247', 'neco', '35'],
#  ['1248', 'aidon', '24'],
#  ['1249', 'rolland', '67'],
#  ['1250', 'jocilynn', '78'],
#  ['1251', 'theo', '77'],
#  ['1252', 'fontaine', '33'],
#  ['1253', 'kennard', '71'],
#  ['1254', 'rhondalyn', '37'],
#  ['1255', 'thea', '26'],
#  ['1256', 'pascual', '18'],
#  ['1257', 'lakshmi', '90'],
#  ['1258', 'coralee', '14'],
#  ['1259', 'linnaea', '61'],
#  ['1260', 'millianna', '93'],
#  ['1261', 'jasin', '44'],
#  ['1262', 'jotham', '25'],
#  ['1263', 'rajesh', '41'],
#  ['1264', 'pooja', '32'],
#  ['1265', 'jessye', '86'],
#  ['1266', 'alisande', '88'],
#  ['1267', 'seif', '7'],
#  ['1268', 'pandora', '28'],
#  ['1269', 'mahlet', '13'],
#  ['1270', 'jesicca', '24'],
#  ['1271', 'litsy', '59'],
#  ['1272', 'karrin', '50'],
#  ['1273', 'karrie', '60'],
#  ['1274', 'armida', '95'],
#  ['1275', 'karris', '27'],
#  ['1276', 'natesha', '66'],
#  ['1277', 'nitish', '62'],
#  ['1278', 'marke', '37'],
#  ['1279', 'daion', '31'],
#  ['1280', 'marka', '99'],
#  ['1281', 'jaylenne', '58'],
#  ['1282', 'marko', '21'],
#  ['1283', 'marki', '15'],
#  ['1284', 'bobak', '20'],
#  ['1285', 'gagandeep', '37'],
#  ['1286', 'darya', '83'],
#  ['1287', 'daryn', '97'],
#  ['1288', 'daryl', '74'],
#  ['1289', 'taquisha', '63'],
#  ['1290', 'mylan', '64'],
#  ['1291', 'taiyo', '74'],
#  ['1292', 'mylah', '4'],
#  ['1293', 'marivi', '52'],
#  ['1294', 'taiya', '57'],
#  ['1295', 'tian', '85'],
#  ['1296', 'tiah', '57'],
#  ['1297', 'keinan', '69'],
#  ['1298', 'caniyah', '31'],
#  ['1299', 'tynia', '3'],
#  ['1300', 'yariah', '15'],
#  ['1301', 'tiaa', '64'],
#  ['1302', 'jaloni', '85'],
#  ['1303', 'hoang', '7'],
#  ['1304', 'faduma', '79'],
#  ['1305', 'raionna', '74'],
#  ['1306', 'mayara', '26'],
#  ['1307', 'nysir', '97'],
#  ['1308', 'rilie', '24'],
#  ['1309', 'theotis', '82'],
#  ['1310', 'mayari', '75'],
#  ['1311', 'dantavious', '18'],
#  ['1312', 'leiliana', '83'],
#  ['1313', 'shalaine', '27'],
#  ['1314', 'vianey', '70'],
#  ['1315', 'shalaina', '94'],
#  ['1316', 'chelsia', '95'],
#  ['1317', 'chelsie', '70'],
#  ['1318', 'karsen', '44'],
#  ['1319', 'jabe', '89'],
#  ['1320', 'shanigua', '38'],
#  ['1321', 'tymia', '74'],
#  ['1322', 'anderson', '52'],
#  ['1323', 'yaileen', '69'],
#  ['1324', 'tymir', '20'],
#  ['1325', 'kenyah', '51'],
#  ['1326', 'shanetra', '48'],
#  ['1327', 'ziva', '2'],
#  ['1328', 'anitria', '21'],
#  ['1329', 'chidinma', '21'],
#  ['1330', 'cassara', '36'],
#  ['1331', 'bronx', '12'],
#  ['1332', 'danicka', '13'],
#  ['1333', 'rithik', '99'],
#  ['1334', 'shraga', '84'],
#  ['1335', 'falan', '87'],
#  ['1336', 'laury', '29'],
#  ['1337', 'kalicia', '5'],
#  ['1338', 'leman', '77'],
#  ['1339', 'loryn', '47'],
#  ['1340', 'sanja', '37'],
#  ['1341', 'laura', '15'],
#  ['1342', 'laure', '73'],
#  ['1343', 'lemar', '47'],
#  ['1344', 'lauri', '53'],
#  ['1345', 'macaela', '84'],
#  ['1346', 'pebble', '89'],
#  ['1347', 'aneisa', '46'],
#  ['1348', 'lauro', '93'],
#  ['1349', 'ghazi', '77'],
#  ['1350', 'daivion', '14'],
#  ['1351', 'haileyann', '66'],
#  ['1352', 'jadasia', '2'],
#  ['1353', 'brittnie', '87'],
#  ['1354', 'allianna', '35'],
#  ['1355', 'meghin', '80'],
#  ['1356', 'nykolas', '25'],
#  ['1357', 'shaquina', '45'],
#  ['1358', 'cherry', '28'],
#  ['1359', 'shya', '23'],
#  ['1360', 'jorie', '47'],
#  ['1361', 'remington', '84'],
#  ['1362', 'poseidon', '18'],
#  ['1363', 'chade', '50'],
#  ['1364', 'chadd', '36'],
#  ['1365', 'clayt', '53'],
#  ['1366', 'delsin', '9'],
#  ['1367', 'asael', '44'],
#  ['1368', 'donovan', '94'],
#  ['1369', 'velva', '67'],
#  ['1370', 'cierria', '47'],
#  ['1371', 'murl', '81'],
#  ['1372', 'elgin', '85'],
#  ['1373', 'lilyahna', '78'],
#  ['1374', 'elgie', '4'],
#  ['1375', 'avien', '22'],
#  ['1376', 'zyere', '50'],
#  ['1377', 'madeliene', '73'],
#  ['1378', 'marlon', '50'],
#  ['1379', 'chizaram', '23'],
#  ['1380', 'karrine', '1'],
#  ['1381', 'meily', '65'],
#  ['1382', 'karrina', '43'],
#  ['1383', 'quantavis', '90'],
#  ['1384', 'skya', '28'],
#  ['1385', 'scottie', '99'],
#  ['1386', 'skyy', '9'],
#  ['1387', 'jewels', '88'],
#  ['1388', 'shahrzad', '41'],
#  ['1389', 'aveion', '28'],
#  ['1390', 'keilee', '88'],
#  ['1391', 'ranferi', '85'],
#  ['1392', 'peder', '44'],
#  ['1393', 'keilen', '61'],
#  ['1394', 'korissa', '97'],
#  ['1395', 'keiley', '57'],
#  ['1396', 'tracen', '14'],
#  ['1397', 'tamyah', '53'],
#  ['1398', 'tracee', '73'],
#  ['1399', 'zaidyn', '82'],
#  ['1400', 'tahara', '76'],
#  ['1401', 'tracey', '98'],
#  ['1402', 'persia', '63'],
#  ['1403', 'dashanay', '20'],
#  ['1404', 'tracer', '39'],
#  ['1405', 'jessamy', '71'],
#  ['1406', 'martyn', '23'],
#  ['1407', 'gavin', '68'],
#  ['1408', 'michaelyn', '36'],
#  ['1409', 'lyfe', '42'],
#  ['1410', 'belton', '88'],
#  ['1411', 'dashanae', '11'],
#  ['1412', 'braxtyn', '30'],
#  ['1413', 'eryn', '55'],
#  ['1414', 'tammera', '15'],
#  ['1415', 'camala', '20'],
#  ['1416', 'hydeia', '53'],
#  ['1417', 'happy', '66'],
#  ['1418', 'eternity', '13'],
#  ['1419', 'laneisha', '95'],
#  ['1420', 'ewing', '27'],
#  ['1421', 'vitalia', '44'],
#  ['1422', 'oscar', '89'],
#  ['1423', 'beyonka', '70'],
#  ['1424', 'nahshon', '31'],
#  ['1425', 'tajuana', '72'],
#  ['1426', 'spence', '89'],
#  ['1427', 'vitaliy', '3'],
#  ['1428', 'jaykwon', '76'],
#  ['1429', 'abbigayle', '38'],
#  ['1430', 'javonte', '48'],
#  ['1431', 'kynisha', '24'],
#  ['1432', 'javonta', '95'],
#  ['1433', 'missael', '21'],
#  ['1434', 'tralana', '74'],
#  ['1435', 'crislyn', '23'],
#  ['1436', 'kenishia', '80'],
#  ['1437', 'christyana', '16'],
#  ['1438', 'rawley', '84'],
#  ['1439', 'stevey', '4'],
#  ['1440', 'brenda', '91'],
#  ['1441', 'marilou', '23'],
#  ['1442', 'aissatou', '41'],
#  ['1443', 'brendt', '27'],
#  ['1444', 'antawn', '84'],
#  ['1445', 'steven', '60'],
#  ['1446', 'zissel', '8'],
#  ['1447', 'johnanthony', '51'],
#  ['1448', 'stevee', '9'],
#  ['1449', 'brendy', '7'],
#  ['1450', 'tyriek', '17'],
#  ['1451', 'kiondra', '93'],
#  ['1452', 'kiondre', '39'],
#  ['1453', 'hawra', '37'],
#  ['1454', 'quadree', '5'],
#  ['1455', 'adeyemi', '98'],
#  ['1456', 'susana', '53'],
#  ['1457', 'amylia', '64'],
#  ['1458', 'klayten', '23'],
#  ['1459', 'emberlee', '81'],
#  ['1460', 'susann', '59'],
#  ['1461', 'emberley', '97'],
#  ['1462', 'demarco', '5'],
#  ['1463', 'ileana', '5'],
#  ['1464', 'lilliana', '86'],
#  ['1465', 'seve', '5'],
#  ['1466', 'ariyel', '40'],
#  ['1467', 'lilliann', '47'],
#  ['1468', 'cally', '53'],
#  ['1469', 'gerrit', '67'],
#  ['1470', 'tyshia', '25'],
#  ['1471', 'jakeb', '67'],
#  ['1472', 'calla', '96'],
#  ['1473', 'gerrie', '8'],
#  ['1474', 'jaken', '90'],
#  ['1475', 'fredericka', '95'],
#  ['1476', 'genesi', '21'],
#  ['1477', 'alima', '45'],
#  ['1478', 'navneet', '12'],
#  ['1479', 'genese', '99'],
#  ['1480', 'leilana', '93'],
#  ['1481', 'ranbir', '37'],
#  ['1482', 'shakelia', '65'],
#  ['1483', 'clintona', '70'],
#  ['1484', 'shaquitta', '5'],
#  ['1485', 'lizeth', '25'],
#  ['1486', 'maryjo', '91'],
#  ['1487', 'deneane', '15'],
#  ['1488', 'abimael', '41'],
#  ['1489', 'valdez', '80'],
#  ['1490', 'aaron', '23'],
#  ['1491', 'lizett', '79'],
#  ['1492', 'marinda', '29'],
#  ['1493', 'mekhiya', '40'],
#  ['1494', 'joleen', '20'],
#  ['1495', 'dejuan', '56'],
#  ['1496', 'endy', '58'],
#  ['1497', 'jullianna', '87'],
#  ['1498', 'aneesia', '56'],
#  ['1499', 'emmalou', '4'],
#  ['1500', 'endi', '69']]

# %%
nameStudent = input("enter student name ")
# Out:
# enter student name endi

# %%
for i in range (len(data)):
  if(data[i][1]==nameStudent):
    print(data[i])
# Out:
# ['1500', 'endi', '69']

# %%
marksStudent = input("enter updated marks ")
# Out:
# enter updated marks 40

# %%
for i in range(len(data)):
  if(data[i][1] == nameStudent):
    print("before data",data[i])
    data[i][2] = marksStudent
    print("after data",data[i])
# Out:
# before data ['1500', 'endi', '69']
# after data ['1500', 'endi', '40']

# %%
nameStudent = input("enter you name")
for i in range(len(data)):
  if(data[i][1]==nameStudent):
    print(data[i])

marksStudent = input("enter the marks you want to change")

for i in range(len(data)):
  if(data[i][1]==nameStudent):
    print("before", data[i])
  if(data[i][2]==marksStudent):
    print("after", data[i])
# Out:
# enter you namelizeth
# ['1485', 'lizeth', '25']
# enter the marks you want to change78
# after ['1030', 'jorell', '78']
# after ['1250', 'jocilynn', '78']
# after ['1373', 'lilyahna', '78']
# before ['1485', 'lizeth', '25']

# %%
for i in range(len(data)):
  if(data[i][2] <= str(20)):
    print(data[i][1])
# Out:
# charelle
# lyberti
# milissa
# johnita
# nonnie
# danamarie
# ladarion
# swayze
# harvey
# halona
# ziair
# kayci
# kayce
# khylei
# mihail
# maccoy
# shaquell
# jayliana
# cope
# even
# akaash
# jannett
# robertson
# kahlel
# tanmay
# chivas
# nigel
# mizraim
# ciaran
# daddy
# xaria
# pascual
# coralee
# mahlet
# marki
# bobak
# yariah
# dantavious
# tymir
# ziva
# bronx
# danicka
# laura
# daivion
# jadasia
# poseidon
# karrine
# tracen
# dashanay
# dashanae
# tammera
# camala
# eternity
# christyana
# tyriek
# navneet
# deneane
# joleen

# %%
for i in range(len(data)):
  if(data[i][1][0]==str('r')):
    print(data[i][1])
# Out:
# rory
# rayleigh
# ramonia
# randell
# rakita
# raiquan
# rayssa
# robertson
# reneta
# rubina
# royer
# rosealie
# rania
# rolland
# rhondalyn
# rajesh
# raionna
# rilie
# rithik
# remington
# ranferi
# rawley
# ranbir
